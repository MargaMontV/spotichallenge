# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = # CLIENT ID
client_secret = # CLIENT SECRET
auth_url = 'https://accounts.spotify.com/api/token'
# Out:
#   Cell In[29], line 3
#     client_id = # CLIENT ID
#                 ^
# SyntaxError: invalid syntax

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
#auth_response

# %%
#access_token = auth_response['access_token']
#access_token

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
#header_info

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI
base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'
artist_id = '26dSoYclwsYLMAKD3tpOr4'
method_01 = '/related-artists'
method_02 = '/top-tracks'
country = '?country=ES'
full_endpoint = base_url + resource + artist_id 
full_endpoint
#requests.get('https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4', headers = header_info)
# Out:
# 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4'

# %%
res = requests.get(full_endpoint, headers = header_info)
res
# Out:
# <Response [200]>

# %%
res_dict = res.json()
res_dict.keys()
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
key_list = res_dict.keys()
key_list
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
full_endpoint_01 = full_endpoint + method_01   # + country
print(full_endpoint)

res_01 = requests.get(full_endpoint_01, headers=header_info)
res_01
# Out:
# https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4
# <Response [200]>

# %%
res_01_dict = res_01.json()
res_01_dict
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#    'followers': {'href': None, 'total': 5890305},
#    'genres': ['dance pop', 'pop'],
#    'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#    'id': '4yiQZ8tQPux8cPriYMWUFP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb71a84376c2d99dbc4eba4097',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517471a84376c2d99dbc4eba4097',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17871a84376c2d99dbc4eba4097',
#      'width': 160}],
#    'name': 'Gwen Stefani',
#    'popularity': 74,
#    'type': 'artist',
#    'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vkJFCwstOoJO7yQ4lTtLK'},
#    'followers': {'href': None, 'total': 687099},
#    'genres': ['dance pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/1vkJFCwstOoJO7yQ4lTtLK',
#    'id': '1vkJFCwstOoJO7yQ4lTtLK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb461938740bb5e26d1bb7849b',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174461938740bb5e26d1bb7849b',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178461938740bb5e26d1bb7849b',
#      'width': 160}],
#    'name': 'Paris Hilton',
#    'popularity': 54,
#    'type': 'artist',
#    'uri': 'spotify:artist:1vkJFCwstOoJO7yQ4lTtLK'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3r17AfJCCUqC9Lf0OAc73G'},
#    'followers': {'href': None, 'total': 5363367},
#    'genres': ['dance pop', 'pop', 'post-teen pop', 'rap'],
#    'href': 'https://api.spotify.com/v1/artists/3r17AfJCCUqC9Lf0OAc73G',
#    'id': '3r17AfJCCUqC9Lf0OAc73G',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb1fd1c6d465e03a904d63c9b5',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051741fd1c6d465e03a904d63c9b5',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1781fd1c6d465e03a904d63c9b5',
#      'width': 160}],
#    'name': 'Fergie',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:3r17AfJCCUqC9Lf0OAc73G'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2gsggkzM5R49q6jpPvazou'},
#    'followers': {'href': None, 'total': 10999476},
#    'genres': ['dance pop', 'pop', 'pop rap', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/2gsggkzM5R49q6jpPvazou',
#    'id': '2gsggkzM5R49q6jpPvazou',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb91f0dd753c09e051675a1ca6',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517491f0dd753c09e051675a1ca6',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17891f0dd753c09e051675a1ca6',
#      'width': 160}],
#    'name': 'Jessie J',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:2gsggkzM5R49q6jpPvazou'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2S9W9aSAd7e5mp8WqWxN2h'},
#    'followers': {'href': None, 'total': 2244616},
#    'genres': ['dance pop', 'neo mellow', 'pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/2S9W9aSAd7e5mp8WqWxN2h',
#    'id': '2S9W9aSAd7e5mp8WqWxN2h',
#    'images': [{'height': 563,
#      'url': 'https://i.scdn.co/image/2b46c43a2c8d3af23f3183299c2070c2d42ad039',
#      'width': 1000},
#     {'height': 360,
#      'url': 'https://i.scdn.co/image/df2f2f41ff8aa1f1d24c12a5e0c96fd66b3a975e',
#      'width': 640},
#     {'height': 113,
#      'url': 'https://i.scdn.co/image/d08392366ca41c605b91c88d933925932a007a92',
#      'width': 200},
#     {'height': 36,
#      'url': 'https://i.scdn.co/image/39b33c98173f680cb6c2a4eea3d7e8823017fb2f',
#      'width': 64}],
#    'name': 'Hilary Duff',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:2S9W9aSAd7e5mp8WqWxN2h'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1l7ZsJRRS8wlW3WfJfPfNS'},
#    'followers': {'href': None, 'total': 7470743},
#    'genres': ['dance pop', 'pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/1l7ZsJRRS8wlW3WfJfPfNS',
#    'id': '1l7ZsJRRS8wlW3WfJfPfNS',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb371cba21c6962a457c550b81',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174371cba21c6962a457c550b81',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178371cba21c6962a457c550b81',
#      'width': 160}],
#    'name': 'Christina Aguilera',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:1l7ZsJRRS8wlW3WfJfPfNS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6dJeKm76NjfXBNTpHmOhfO'},
#    'followers': {'href': None, 'total': 8559964},
#    'genres': ['dance pop', 'pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/6dJeKm76NjfXBNTpHmOhfO',
#    'id': '6dJeKm76NjfXBNTpHmOhfO',
#    'images': [{'height': 1333,
#      'url': 'https://i.scdn.co/image/469b6a74f5ddca9560e9f5137842e3772c8576c0',
#      'width': 1000},
#     {'height': 853,
#      'url': 'https://i.scdn.co/image/e732af47c9b0c55a56a2eb9dc554928212f344bb',
#      'width': 640},
#     {'height': 267,
#      'url': 'https://i.scdn.co/image/b73fec33c90639d9586681afffcf6773d48a8103',
#      'width': 200},
#     {'height': 85,
#      'url': 'https://i.scdn.co/image/ed02316da670954a09d1283204724e7987408611',
#      'width': 64}],
#    'name': 'Selena Gomez & The Scene',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:6dJeKm76NjfXBNTpHmOhfO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#    'followers': {'href': None, 'total': 9674161},
#    'genres': ['canadian pop',
#     'candy pop',
#     'dance pop',
#     'pop',
#     'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#    'id': '0p4nmQO2msCgU4IF37Wi3j',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb581efa688945cbb092df1726',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174581efa688945cbb092df1726',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178581efa688945cbb092df1726',
#      'width': 160}],
#    'name': 'Avril Lavigne',
#    'popularity': 78,
#    'type': 'artist',
#    'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hqDqHtBlgxXpLXVYf7c8L'},
#    'followers': {'href': None, 'total': 918895},
#    'genres': ['dance pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/4hqDqHtBlgxXpLXVYf7c8L',
#    'id': '4hqDqHtBlgxXpLXVYf7c8L',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb60a34dfbd606cefc93c33310',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517460a34dfbd606cefc93c33310',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17860a34dfbd606cefc93c33310',
#      'width': 160}],
#    'name': 'Ashlee Simpson',
#    'popularity': 50,
#    'type': 'artist',
#    'uri': 'spotify:artist:4hqDqHtBlgxXpLXVYf7c8L'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tbjWDEIzxoDsBA1FuhfPW'},
#    'followers': {'href': None, 'total': 6820251},
#    'genres': ['dance pop', 'pop'],
#    'href': 'https://api.spotify.com/v1/artists/6tbjWDEIzxoDsBA1FuhfPW',
#    'id': '6tbjWDEIzxoDsBA1FuhfPW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb4b36d28b55620959821f4a5b',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051744b36d28b55620959821f4a5b',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1784b36d28b55620959821f4a5b',
#      'width': 160}],
#    'name': 'Madonna',
#    'popularity': 80,
#    'type': 'artist',
#    'uri': 'spotify:artist:6tbjWDEIzxoDsBA1FuhfPW'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xuNBZoM7z1Vv8IQ6uM0p6'},
#    'followers': {'href': None, 'total': 2278989},
#    'genres': ['dance pop',
#     'pop',
#     'post-teen pop',
#     'r&b',
#     'urban contemporary'],
#    'href': 'https://api.spotify.com/v1/artists/5xuNBZoM7z1Vv8IQ6uM0p6',
#    'id': '5xuNBZoM7z1Vv8IQ6uM0p6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebc1a9f80f732a8dc4eab18d3f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174c1a9f80f732a8dc4eab18d3f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178c1a9f80f732a8dc4eab18d3f',
#      'width': 160}],
#    'name': 'JoJo',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:5xuNBZoM7z1Vv8IQ6uM0p6'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7o95ZoZt5ZYn31e9z1Hc0a'},
#    'followers': {'href': None, 'total': 1566111},
#    'genres': ['dance pop',
#     'europop',
#     'neo mellow',
#     'pop',
#     'pop rock',
#     'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/7o95ZoZt5ZYn31e9z1Hc0a',
#    'id': '7o95ZoZt5ZYn31e9z1Hc0a',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb32432b578e9cbd20fcedf9d1',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517432432b578e9cbd20fcedf9d1',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17832432b578e9cbd20fcedf9d1',
#      'width': 160}],
#    'name': 'Natasha Bedingfield',
#    'popularity': 67,
#    'type': 'artist',
#    'uri': 'spotify:artist:7o95ZoZt5ZYn31e9z1Hc0a'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wugb0kaq0J6nyQ5Xgd17i'},
#    'followers': {'href': None, 'total': 639611},
#    'genres': ['dance pop',
#     'electropop',
#     'girl group',
#     'indie pop',
#     'neo mellow',
#     'pop',
#     'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/5wugb0kaq0J6nyQ5Xgd17i',
#    'id': '5wugb0kaq0J6nyQ5Xgd17i',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb72c976a5d83100474da24bc3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517472c976a5d83100474da24bc3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17872c976a5d83100474da24bc3',
#      'width': 160}],
#    'name': 'Aly & AJ',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:5wugb0kaq0J6nyQ5Xgd17i'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0uq5PttqEjj3IH1bzwcrXF'},
#    'followers': {'href': None, 'total': 3014902},
#    'genres': ['dance pop', 'europop', 'girl group'],
#    'href': 'https://api.spotify.com/v1/artists/0uq5PttqEjj3IH1bzwcrXF',
#    'id': '0uq5PttqEjj3IH1bzwcrXF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebcf4a1dced6258416eb219e36',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174cf4a1dced6258416eb219e36',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178cf4a1dced6258416eb219e36',
#      'width': 160}],
#    'name': 'Spice Girls',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:0uq5PttqEjj3IH1bzwcrXF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6S2OmqARrzebs0tKUEyXyp'},
#    'followers': {'href': None, 'total': 24506972},
#    'genres': ['dance pop', 'pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/6S2OmqARrzebs0tKUEyXyp',
#    'id': '6S2OmqARrzebs0tKUEyXyp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6659b1cb61936bd7bcb229a2',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746659b1cb61936bd7bcb229a2',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786659b1cb61936bd7bcb229a2',
#      'width': 160}],
#    'name': 'Demi Lovato',
#    'popularity': 80,
#    'type': 'artist',
#    'uri': 'spotify:artist:6S2OmqARrzebs0tKUEyXyp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y8cdNmUJH7yBTd9yOvr5i'},
#    'followers': {'href': None, 'total': 6245613},
#    'genres': ['dance pop',
#     'girl group',
#     'hip pop',
#     'pop',
#     'r&b',
#     'urban contemporary'],
#    'href': 'https://api.spotify.com/v1/artists/1Y8cdNmUJH7yBTd9yOvr5i',
#    'id': '1Y8cdNmUJH7yBTd9yOvr5i',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebf75e64532704bd6acf0b4e76',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174f75e64532704bd6acf0b4e76',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178f75e64532704bd6acf0b4e76',
#      'width': 160}],
#    'name': "Destiny's Child",
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2tFN9ubMXEhdAQvdQxcsma'},
#    'followers': {'href': None, 'total': 1205166},
#    'genres': ['dance pop', 'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/2tFN9ubMXEhdAQvdQxcsma',
#    'id': '2tFN9ubMXEhdAQvdQxcsma',
#    'images': [{'height': 1250,
#      'url': 'https://i.scdn.co/image/82af2788a1423143a5edd5ec1c3301df85717590',
#      'width': 1000},
#     {'height': 800,
#      'url': 'https://i.scdn.co/image/5a651729912dbaa72e2a197fef1e9d8425b93cbc',
#      'width': 640},
#     {'height': 250,
#      'url': 'https://i.scdn.co/image/577f3f86d35528976f624d75a66c480ef3340db9',
#      'width': 200},
#     {'height': 80,
#      'url': 'https://i.scdn.co/image/40ec117ab667287074927c90741e7d2f4847b0fd',
#      'width': 64}],
#    'name': 'Jessica Simpson',
#    'popularity': 51,
#    'type': 'artist',
#    'uri': 'spotify:artist:2tFN9ubMXEhdAQvdQxcsma'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#    'followers': {'href': None, 'total': 9602102},
#    'genres': ['dance pop', 'pop', 'post-teen pop', 'talent show'],
#    'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#    'id': '3BmGtnKgCSGYIUhmivXKWX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb118cd1f3261f08d957105996',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174118cd1f3261f08d957105996',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178118cd1f3261f08d957105996',
#      'width': 160}],
#    'name': 'Kelly Clarkson',
#    'popularity': 75,
#    'type': 'artist',
#    'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4RVnAU35WRWra6OZ3CbbMA'},
#    'followers': {'href': None, 'total': 1644257},
#    'genres': ['australian dance',
#     'australian pop',
#     'dance pop',
#     'electropop',
#     'eurodance',
#     'europop',
#     'new wave pop',
#     'pop'],
#    'href': 'https://api.spotify.com/v1/artists/4RVnAU35WRWra6OZ3CbbMA',
#    'id': '4RVnAU35WRWra6OZ3CbbMA',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebab2720cd7161ed8a2a203f3a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174ab2720cd7161ed8a2a203f3a',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178ab2720cd7161ed8a2a203f3a',
#      'width': 160}],
#    'name': 'Kylie Minogue',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:4RVnAU35WRWra6OZ3CbbMA'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dIdBZaaHRW2bDTkHNfWln'},
#    'followers': {'href': None, 'total': 911863},
#    'genres': ['australian pop',
#     'australian talent show',
#     'candy pop',
#     'dance pop',
#     'electropop',
#     'girl group',
#     'pop',
#     'post-teen pop'],
#    'href': 'https://api.spotify.com/v1/artists/1dIdBZaaHRW2bDTkHNfWln',
#    'id': '1dIdBZaaHRW2bDTkHNfWln',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6b35f6afa8b8f9758ab6f14f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746b35f6afa8b8f9758ab6f14f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786b35f6afa8b8f9758ab6f14f',
#      'width': 160}],
#    'name': 'The Veronicas',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:1dIdBZaaHRW2bDTkHNfWln'}]}

# %%
res_01_dict.keys()
# Out:
# dict_keys(['artists'])

# %%
len(res_01_dict['artists'])

# %%
res_01_dict['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#   'followers': {'href': None, 'total': 5890305},
#   'genres': ['dance pop', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#   'id': '4yiQZ8tQPux8cPriYMWUFP',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb71a84376c2d99dbc4eba4097',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517471a84376c2d99dbc4eba4097',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17871a84376c2d99dbc4eba4097',
#     'width': 160}],
#   'name': 'Gwen Stefani',
#   'popularity': 74,
#   'type': 'artist',
#   'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vkJFCwstOoJO7yQ4lTtLK'},
#   'followers': {'href': None, 'total': 687099},
#   'genres': ['dance pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/1vkJFCwstOoJO7yQ4lTtLK',
#   'id': '1vkJFCwstOoJO7yQ4lTtLK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb461938740bb5e26d1bb7849b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174461938740bb5e26d1bb7849b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178461938740bb5e26d1bb7849b',
#     'width': 160}],
#   'name': 'Paris Hilton',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:1vkJFCwstOoJO7yQ4lTtLK'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3r17AfJCCUqC9Lf0OAc73G'},
#   'followers': {'href': None, 'total': 5363367},
#   'genres': ['dance pop', 'pop', 'post-teen pop', 'rap'],
#   'href': 'https://api.spotify.com/v1/artists/3r17AfJCCUqC9Lf0OAc73G',
#   'id': '3r17AfJCCUqC9Lf0OAc73G',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb1fd1c6d465e03a904d63c9b5',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051741fd1c6d465e03a904d63c9b5',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1781fd1c6d465e03a904d63c9b5',
#     'width': 160}],
#   'name': 'Fergie',
#   'popularity': 71,
#   'type': 'artist',
#   'uri': 'spotify:artist:3r17AfJCCUqC9Lf0OAc73G'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2gsggkzM5R49q6jpPvazou'},
#   'followers': {'href': None, 'total': 10999476},
#   'genres': ['dance pop', 'pop', 'pop rap', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/2gsggkzM5R49q6jpPvazou',
#   'id': '2gsggkzM5R49q6jpPvazou',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb91f0dd753c09e051675a1ca6',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517491f0dd753c09e051675a1ca6',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17891f0dd753c09e051675a1ca6',
#     'width': 160}],
#   'name': 'Jessie J',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:2gsggkzM5R49q6jpPvazou'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2S9W9aSAd7e5mp8WqWxN2h'},
#   'followers': {'href': None, 'total': 2244616},
#   'genres': ['dance pop', 'neo mellow', 'pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/2S9W9aSAd7e5mp8WqWxN2h',
#   'id': '2S9W9aSAd7e5mp8WqWxN2h',
#   'images': [{'height': 563,
#     'url': 'https://i.scdn.co/image/2b46c43a2c8d3af23f3183299c2070c2d42ad039',
#     'width': 1000},
#    {'height': 360,
#     'url': 'https://i.scdn.co/image/df2f2f41ff8aa1f1d24c12a5e0c96fd66b3a975e',
#     'width': 640},
#    {'height': 113,
#     'url': 'https://i.scdn.co/image/d08392366ca41c605b91c88d933925932a007a92',
#     'width': 200},
#    {'height': 36,
#     'url': 'https://i.scdn.co/image/39b33c98173f680cb6c2a4eea3d7e8823017fb2f',
#     'width': 64}],
#   'name': 'Hilary Duff',
#   'popularity': 58,
#   'type': 'artist',
#   'uri': 'spotify:artist:2S9W9aSAd7e5mp8WqWxN2h'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1l7ZsJRRS8wlW3WfJfPfNS'},
#   'followers': {'href': None, 'total': 7470743},
#   'genres': ['dance pop', 'pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/1l7ZsJRRS8wlW3WfJfPfNS',
#   'id': '1l7ZsJRRS8wlW3WfJfPfNS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb371cba21c6962a457c550b81',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174371cba21c6962a457c550b81',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178371cba21c6962a457c550b81',
#     'width': 160}],
#   'name': 'Christina Aguilera',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:1l7ZsJRRS8wlW3WfJfPfNS'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6dJeKm76NjfXBNTpHmOhfO'},
#   'followers': {'href': None, 'total': 8559964},
#   'genres': ['dance pop', 'pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/6dJeKm76NjfXBNTpHmOhfO',
#   'id': '6dJeKm76NjfXBNTpHmOhfO',
#   'images': [{'height': 1333,
#     'url': 'https://i.scdn.co/image/469b6a74f5ddca9560e9f5137842e3772c8576c0',
#     'width': 1000},
#    {'height': 853,
#     'url': 'https://i.scdn.co/image/e732af47c9b0c55a56a2eb9dc554928212f344bb',
#     'width': 640},
#    {'height': 267,
#     'url': 'https://i.scdn.co/image/b73fec33c90639d9586681afffcf6773d48a8103',
#     'width': 200},
#    {'height': 85,
#     'url': 'https://i.scdn.co/image/ed02316da670954a09d1283204724e7987408611',
#     'width': 64}],
#   'name': 'Selena Gomez & The Scene',
#   'popularity': 72,
#   'type': 'artist',
#   'uri': 'spotify:artist:6dJeKm76NjfXBNTpHmOhfO'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#   'followers': {'href': None, 'total': 9674161},
#   'genres': ['canadian pop', 'candy pop', 'dance pop', 'pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#   'id': '0p4nmQO2msCgU4IF37Wi3j',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb581efa688945cbb092df1726',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174581efa688945cbb092df1726',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178581efa688945cbb092df1726',
#     'width': 160}],
#   'name': 'Avril Lavigne',
#   'popularity': 78,
#   'type': 'artist',
#   'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hqDqHtBlgxXpLXVYf7c8L'},
#   'followers': {'href': None, 'total': 918895},
#   'genres': ['dance pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/4hqDqHtBlgxXpLXVYf7c8L',
#   'id': '4hqDqHtBlgxXpLXVYf7c8L',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb60a34dfbd606cefc93c33310',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517460a34dfbd606cefc93c33310',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17860a34dfbd606cefc93c33310',
#     'width': 160}],
#   'name': 'Ashlee Simpson',
#   'popularity': 50,
#   'type': 'artist',
#   'uri': 'spotify:artist:4hqDqHtBlgxXpLXVYf7c8L'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tbjWDEIzxoDsBA1FuhfPW'},
#   'followers': {'href': None, 'total': 6820251},
#   'genres': ['dance pop', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/6tbjWDEIzxoDsBA1FuhfPW',
#   'id': '6tbjWDEIzxoDsBA1FuhfPW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb4b36d28b55620959821f4a5b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051744b36d28b55620959821f4a5b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1784b36d28b55620959821f4a5b',
#     'width': 160}],
#   'name': 'Madonna',
#   'popularity': 80,
#   'type': 'artist',
#   'uri': 'spotify:artist:6tbjWDEIzxoDsBA1FuhfPW'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xuNBZoM7z1Vv8IQ6uM0p6'},
#   'followers': {'href': None, 'total': 2278989},
#   'genres': ['dance pop', 'pop', 'post-teen pop', 'r&b', 'urban contemporary'],
#   'href': 'https://api.spotify.com/v1/artists/5xuNBZoM7z1Vv8IQ6uM0p6',
#   'id': '5xuNBZoM7z1Vv8IQ6uM0p6',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc1a9f80f732a8dc4eab18d3f',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c1a9f80f732a8dc4eab18d3f',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c1a9f80f732a8dc4eab18d3f',
#     'width': 160}],
#   'name': 'JoJo',
#   'popularity': 64,
#   'type': 'artist',
#   'uri': 'spotify:artist:5xuNBZoM7z1Vv8IQ6uM0p6'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7o95ZoZt5ZYn31e9z1Hc0a'},
#   'followers': {'href': None, 'total': 1566111},
#   'genres': ['dance pop',
#    'europop',
#    'neo mellow',
#    'pop',
#    'pop rock',
#    'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/7o95ZoZt5ZYn31e9z1Hc0a',
#   'id': '7o95ZoZt5ZYn31e9z1Hc0a',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb32432b578e9cbd20fcedf9d1',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517432432b578e9cbd20fcedf9d1',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17832432b578e9cbd20fcedf9d1',
#     'width': 160}],
#   'name': 'Natasha Bedingfield',
#   'popularity': 67,
#   'type': 'artist',
#   'uri': 'spotify:artist:7o95ZoZt5ZYn31e9z1Hc0a'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wugb0kaq0J6nyQ5Xgd17i'},
#   'followers': {'href': None, 'total': 639611},
#   'genres': ['dance pop',
#    'electropop',
#    'girl group',
#    'indie pop',
#    'neo mellow',
#    'pop',
#    'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/5wugb0kaq0J6nyQ5Xgd17i',
#   'id': '5wugb0kaq0J6nyQ5Xgd17i',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb72c976a5d83100474da24bc3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517472c976a5d83100474da24bc3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17872c976a5d83100474da24bc3',
#     'width': 160}],
#   'name': 'Aly & AJ',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:5wugb0kaq0J6nyQ5Xgd17i'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0uq5PttqEjj3IH1bzwcrXF'},
#   'followers': {'href': None, 'total': 3014902},
#   'genres': ['dance pop', 'europop', 'girl group'],
#   'href': 'https://api.spotify.com/v1/artists/0uq5PttqEjj3IH1bzwcrXF',
#   'id': '0uq5PttqEjj3IH1bzwcrXF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebcf4a1dced6258416eb219e36',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174cf4a1dced6258416eb219e36',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178cf4a1dced6258416eb219e36',
#     'width': 160}],
#   'name': 'Spice Girls',
#   'popularity': 70,
#   'type': 'artist',
#   'uri': 'spotify:artist:0uq5PttqEjj3IH1bzwcrXF'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6S2OmqARrzebs0tKUEyXyp'},
#   'followers': {'href': None, 'total': 24506972},
#   'genres': ['dance pop', 'pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/6S2OmqARrzebs0tKUEyXyp',
#   'id': '6S2OmqARrzebs0tKUEyXyp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb6659b1cb61936bd7bcb229a2',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051746659b1cb61936bd7bcb229a2',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1786659b1cb61936bd7bcb229a2',
#     'width': 160}],
#   'name': 'Demi Lovato',
#   'popularity': 80,
#   'type': 'artist',
#   'uri': 'spotify:artist:6S2OmqARrzebs0tKUEyXyp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y8cdNmUJH7yBTd9yOvr5i'},
#   'followers': {'href': None, 'total': 6245613},
#   'genres': ['dance pop',
#    'girl group',
#    'hip pop',
#    'pop',
#    'r&b',
#    'urban contemporary'],
#   'href': 'https://api.spotify.com/v1/artists/1Y8cdNmUJH7yBTd9yOvr5i',
#   'id': '1Y8cdNmUJH7yBTd9yOvr5i',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebf75e64532704bd6acf0b4e76',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174f75e64532704bd6acf0b4e76',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178f75e64532704bd6acf0b4e76',
#     'width': 160}],
#   'name': "Destiny's Child",
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2tFN9ubMXEhdAQvdQxcsma'},
#   'followers': {'href': None, 'total': 1205166},
#   'genres': ['dance pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/2tFN9ubMXEhdAQvdQxcsma',
#   'id': '2tFN9ubMXEhdAQvdQxcsma',
#   'images': [{'height': 1250,
#     'url': 'https://i.scdn.co/image/82af2788a1423143a5edd5ec1c3301df85717590',
#     'width': 1000},
#    {'height': 800,
#     'url': 'https://i.scdn.co/image/5a651729912dbaa72e2a197fef1e9d8425b93cbc',
#     'width': 640},
#    {'height': 250,
#     'url': 'https://i.scdn.co/image/577f3f86d35528976f624d75a66c480ef3340db9',
#     'width': 200},
#    {'height': 80,
#     'url': 'https://i.scdn.co/image/40ec117ab667287074927c90741e7d2f4847b0fd',
#     'width': 64}],
#   'name': 'Jessica Simpson',
#   'popularity': 51,
#   'type': 'artist',
#   'uri': 'spotify:artist:2tFN9ubMXEhdAQvdQxcsma'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#   'followers': {'href': None, 'total': 9602102},
#   'genres': ['dance pop', 'pop', 'post-teen pop', 'talent show'],
#   'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#   'id': '3BmGtnKgCSGYIUhmivXKWX',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb118cd1f3261f08d957105996',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174118cd1f3261f08d957105996',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178118cd1f3261f08d957105996',
#     'width': 160}],
#   'name': 'Kelly Clarkson',
#   'popularity': 75,
#   'type': 'artist',
#   'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4RVnAU35WRWra6OZ3CbbMA'},
#   'followers': {'href': None, 'total': 1644257},
#   'genres': ['australian dance',
#    'australian pop',
#    'dance pop',
#    'electropop',
#    'eurodance',
#    'europop',
#    'new wave pop',
#    'pop'],
#   'href': 'https://api.spotify.com/v1/artists/4RVnAU35WRWra6OZ3CbbMA',
#   'id': '4RVnAU35WRWra6OZ3CbbMA',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebab2720cd7161ed8a2a203f3a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174ab2720cd7161ed8a2a203f3a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178ab2720cd7161ed8a2a203f3a',
#     'width': 160}],
#   'name': 'Kylie Minogue',
#   'popularity': 70,
#   'type': 'artist',
#   'uri': 'spotify:artist:4RVnAU35WRWra6OZ3CbbMA'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dIdBZaaHRW2bDTkHNfWln'},
#   'followers': {'href': None, 'total': 911863},
#   'genres': ['australian pop',
#    'australian talent show',
#    'candy pop',
#    'dance pop',
#    'electropop',
#    'girl group',
#    'pop',
#    'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/1dIdBZaaHRW2bDTkHNfWln',
#   'id': '1dIdBZaaHRW2bDTkHNfWln',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb6b35f6afa8b8f9758ab6f14f',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051746b35f6afa8b8f9758ab6f14f',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1786b35f6afa8b8f9758ab6f14f',
#     'width': 160}],
#   'name': 'The Veronicas',
#   'popularity': 57,
#   'type': 'artist',
#   'uri': 'spotify:artist:1dIdBZaaHRW2bDTkHNfWln'}]

# %%
res_01_dict['artists'][0]['name']
# Out:
# 'Gwen Stefani'

# %%
artists_list = [res_01_dict['artists'][artista]['id'] for artista in range(len(res_01_dict['artists']))]
artists_list
# Out:
# ['4yiQZ8tQPux8cPriYMWUFP',
#  '1vkJFCwstOoJO7yQ4lTtLK',
#  '3r17AfJCCUqC9Lf0OAc73G',
#  '2gsggkzM5R49q6jpPvazou',
#  '2S9W9aSAd7e5mp8WqWxN2h',
#  '1l7ZsJRRS8wlW3WfJfPfNS',
#  '6dJeKm76NjfXBNTpHmOhfO',
#  '0p4nmQO2msCgU4IF37Wi3j',
#  '4hqDqHtBlgxXpLXVYf7c8L',
#  '6tbjWDEIzxoDsBA1FuhfPW',
#  '5xuNBZoM7z1Vv8IQ6uM0p6',
#  '7o95ZoZt5ZYn31e9z1Hc0a',
#  '5wugb0kaq0J6nyQ5Xgd17i',
#  '0uq5PttqEjj3IH1bzwcrXF',
#  '6S2OmqARrzebs0tKUEyXyp',
#  '1Y8cdNmUJH7yBTd9yOvr5i',
#  '2tFN9ubMXEhdAQvdQxcsma',
#  '3BmGtnKgCSGYIUhmivXKWX',
#  '4RVnAU35WRWra6OZ3CbbMA',
#  '1dIdBZaaHRW2bDTkHNfWln']

# %%
full_endpoint_02 = full_endpoint + method_02 + country
print(full_endpoint_02)

res_02 = requests.get(full_endpoint_02, headers=header_info)
res_02
# Out:
# https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4/top-tracks?country=ES
# <Response [200]>

# %%
full_endpoint_03 = base_url + resource + '{}' + method_02 + country
print(full_endpoint_03)

for artist in artists_list:
    response = requests.get(full_endpoint_03.format(artist), headers=header_info)
    print([response.json()['tracks'][track]['name'] for track in range(len(response.json()['tracks']))])
# Out:
# https://api.spotify.com/v1/artists/{}/top-tracks?country=ES
# ['The Sweet Escape', 'Hollaback Girl', 'Rich Girl', 'Luxurious', 'Bubble Pop Electric', 'What You Waiting For?', "CAN'T STOP THE FEELING! - Film Version", 'Cool', "Move Your Feet / D.A.N.C.E. / It's A Sunshine Day", 'You Make It Feel Like Christmas (feat. Blake Shelton)']
# ['Stars Are Blind', 'Zydrate Anatomy', 'Nothing in This World', 'Stars Are Blind - Luny Tunes Remix; feat. Wisin and Yandel', "Do Ya Think I'm Sexy", 'I Blame You', "Best Friend's Ass", 'Turn It Up', 'Turn You On', "Best Friend's Ass - Dimitri Vegas & Like Mike Remix"]
# ['Glamorous', "Big Girls Don't Cry (Personal)", 'Fergalicious', 'London Bridge', 'A Little Party Never Killed Nobody (All We Got)', 'Clumsy', 'L.A.LOVE (la la) [feat. YG]', 'M.I.L.F. $', 'London Bridge', 'Glamorous']
# ['Bang Bang', 'Price Tag', 'Domino', 'Flashlight - From "Pitch Perfect 2" Soundtrack', 'Who You Are', 'Do It Like A Dude', 'Sexy Lady', 'Masterpiece', 'I Want Love', 'Price Tag - Acoustic Version']
# ['Come Clean', 'What Dreams Are Made Of', 'So Yesterday', 'Why Not', 'Wake Up', 'Sparks', "Someone's Watching Over Me", 'Fly', 'With Love', 'Stranger']
# ['Moves Like Jagger - Studio Recording From The Voice Performance', 'Feel This Moment (feat. Christina Aguilera)', 'Say Something', 'Lady Marmalade - Single Edit', 'El Ultimo Adiós - Varios Artistas Version', 'Genie In a Bottle', 'Beautiful', 'Dirrty (feat. Redman)', 'Fighter', 'Candyman']
# ['Love You Like A Love Song', 'Who Says', 'Naturally', 'A Year Without Rain', 'Hit The Lights', 'Round & Round', "Tell Me Something I Don't Know", 'Un Año Sin Lluvia', 'My Dilemma', 'My Dilemma 2.0']
# ['Complicated', 'Sk8er Boi', 'Girlfriend', 'What the Hell', "I'm with You", 'My Happy Ending', "When You're Gone", 'Bite Me', 'I’m a Mess (with YUNGBLUD)', "Here's to Never Growing Up"]
# ['Pieces Of Me', 'Boyfriend', 'La La', 'L.O.V.E.', 'Outta My Head (Ay Ya Ya) - New Edit', 'Autobiography', 'Shadow', 'Invisible', 'Love Me For Me', 'Better Off']
# ['Hung Up', 'La Isla Bonita', 'Material Girl', '4 Minutes (feat. Justin Timberlake & Timbaland)', 'Back That Up To The Beat - demo version', 'Frozen', 'Like a Prayer', 'Like a Virgin', 'Vogue', 'Back That Up To The Beat - sped up version']
# ['Too Little Too Late', 'Leave (Get Out)', "Baby It's You", 'Too Little Too Late - 2018', 'Comeback (feat. Tory Lanez and 30 Roc)', 'Leave (Get Out) - 2018', 'High Heels.', 'Fuck Apologies. (feat. Wiz Khalifa)', "Baby It's You - 2018", 'Spiral SZN']
# ['Unwritten', 'Pocketful of Sunshine', 'These Words', 'Love Like This (feat. Sean Kingston)', 'Soulmate', 'Love Song to the Earth', 'Wild Horses', 'Who I Am - (From “The Pirate Fairy”)', 'Unwritten - The 2019 Remix', 'Single']
# ['Potential Breakup Song', 'Potential Breakup Song', 'Slow Dancing', 'Baby Lay Your Head Down', 'With Love From', 'After Hours', 'Like Whoa', 'Blue Dress', 'Slow Dancing - Hazel English Remix', 'Walking On Sunshine']
# ['Wannabe', 'Stop', "Say You'll Be There", 'Spice Up Your Life', '2 Become 1', 'Who Do You Think You Are', 'Viva Forever', 'Mama', 'Too Much', 'Goodbye']
# ['Cool for the Summer', 'Heart Attack', 'Sorry Not Sorry', 'Échame La Culpa', 'Confident', 'Solo (feat. Demi Lovato)', 'Give Your Heart a Break', '29', "Really Don't Care", 'Cool for the Summer - Sped Up (Nightcore)']
# ['Say My Name', 'Survivor', 'Bills, Bills, Bills', "Jumpin', Jumpin'", 'Independent Women, Pt. 1 - Pasadena Remix', 'Bootylicious', 'Lose My Breath', 'Cater 2 U', "Soldier (feat. T.I. & Lil' Wayne)", 'Brown Eyes']
# ['I Wanna Love You Forever', 'With You', "I Think I'm in Love with You", "These Boots Are Made for Walkin'", 'Take My Breath Away', 'A Public Affair', 'Irresistible', 'Where You Are (featuring Nick Lachey) (feat. Nick Lachey) - New Version', 'When You Told Me You Loved Me', 'I Belong to Me']
# ['Since U Been Gone', "Stronger (What Doesn't Kill You)", 'Because of You', 'Breakaway', 'My Life Would Suck Without You', 'Underneath the Tree', 'Happier Than Ever', 'Happier Than Ever - Edit', 'Heartbeat Song', 'Behind These Hazel Eyes']
# ["Can't Get You out of My Head", 'In Your Eyes', 'The Loco-Motion', "Can't Get You out of My Head - Peggy Gou’s Midnight Remix", 'A Second to Midnight', 'Love at First Sight', 'Spinning Around', 'Where the Wild Roses Grow - 2011 - Remaster', 'I Should Be So Lucky', 'Santa Baby']
# ['Untouched', '4ever', 'If You Love Someone', 'You Ruin Me', 'In My Blood', 'On Your Side', "Everything I'm Not", 'Take Me on the Floor', 'When It All Falls Apart', 'Hook Me Up']

# %%
#endpoint_related_art_1 = requests.get('https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4/related-artists', 
  #                                   headers = header_info)
#endpoint_related_art_1

# %%
#related_json = endpoint_related_art_1.json()
#related_json.keys()
#df_related_json = pd.DataFrame(related_json['artists'])
#df_related_json.head()
#df_related_json.info()

# %%
#endpoint_top_tracks = requests.get('https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP/top-tracks?country=ES', 
                                     headers = header_info)
#endpoint_top_tracks

# %%
#top_tracks_json = endpoint_top_tracks.json()
#top_tracks_json.keys()
#df_top_tracks_json = pd.DataFrame(top_tracks_json['tracks'])
#df_top_tracks_json.head()
#df_related_json.info()

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
